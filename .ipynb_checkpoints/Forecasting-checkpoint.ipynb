# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import datetime as dt
import seaborn as sns

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('train.csv')

# %%
col = 'date'
df[col] = pd.to_datetime(df[col],format = '%Y-%m-%d')
df['year'] = df[col].dt.year
df['month'] = df[col].dt.month
df['year_month'] = pd.to_datetime(df[col]).dt.to_period('M')

# %%
df.head()
# Out:
#         date  store  item  sales year_month
# 0 2013-01-01      1     1     13    2013-01
# 1 2013-01-02      1     1     11    2013-01
# 2 2013-01-03      1     1     14    2013-01
# 3 2013-01-04      1     1     13    2013-01
# 4 2013-01-05      1     1     10    2013-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 5 columns):
# date          913000 non-null datetime64[ns]
# store         913000 non-null int64
# item          913000 non-null int64
# sales         913000 non-null int64
# year_month    913000 non-null period[M]
# dtypes: datetime64[ns](1), int64(3), period[M](1)
# memory usage: 34.8 MB

# %%
missing_values = ["n/a", "na", "--"]
df = pd.read_csv("train.csv", na_values = missing_values)

# %%
print(df['sales'])
# Out:
# 0         13
# 1         11
# 2         14
# 3         13
# 4         10
#           ..
# 912995    63
# 912996    59
# 912997    74
# 912998    62
# 912999    82
# Name: sales, Length: 913000, dtype: int64

# %%
print(df['store'])
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 912995    10
# 912996    10
# 912997    10
# 912998    10
# 912999    10
# Name: store, Length: 913000, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 5 columns):
# date          913000 non-null datetime64[ns]
# store         913000 non-null int64
# item          913000 non-null int64
# sales         913000 non-null int64
# year_month    913000 non-null period[M]
# dtypes: datetime64[ns](1), int64(3), period[M](1)
# memory usage: 34.8 MB

# %%
df.head()
# Out:
#         date  store  item  sales year_month
# 0 2013-01-01      1     1     13    2013-01
# 1 2013-01-02      1     1     11    2013-01
# 2 2013-01-03      1     1     14    2013-01
# 3 2013-01-04      1     1     13    2013-01
# 4 2013-01-05      1     1     10    2013-01

# %%
df_grouped = df.groupby(['store']).agg({'sales':['count']}, axis="columns")

# %%
df_g = df.groupby(['store'])

# %%
df_g.head()
# Out:
#             date  store  item  sales year_month
# 0     2013-01-01      1     1     13    2013-01
# 1     2013-01-02      1     1     11    2013-01
# 2     2013-01-03      1     1     14    2013-01
# 3     2013-01-04      1     1     13    2013-01
# 4     2013-01-05      1     1     10    2013-01
# 1826  2013-01-01      2     1     12    2013-01
# 1827  2013-01-02      2     1     16    2013-01
# 1828  2013-01-03      2     1     16    2013-01
# 1829  2013-01-04      2     1     20    2013-01
# 1830  2013-01-05      2     1     16    2013-01
# 3652  2013-01-01      3     1     19    2013-01
# 3653  2013-01-02      3     1      8    2013-01
# 3654  2013-01-03      3     1     10    2013-01
# 3655  2013-01-04      3     1     15    2013-01
# 3656  2013-01-05      3     1     22    2013-01
# 5478  2013-01-01      4     1     10    2013-01
# 5479  2013-01-02      4     1     12    2013-01
# 5480  2013-01-03      4     1      8    2013-01
# 5481  2013-01-04      4     1     15    2013-01
# 5482  2013-01-05      4     1     19    2013-01
# 7304  2013-01-01      5     1     11    2013-01
# 7305  2013-01-02      5     1      9    2013-01
# 7306  2013-01-03      5     1     12    2013-01
# 7307  2013-01-04      5     1      8    2013-01
# 7308  2013-01-05      5     1     13    2013-01
# 9130  2013-01-01      6     1     20    2013-01
# 9131  2013-01-02      6     1      6    2013-01
# 9132  2013-01-03      6     1     11    2013-01
# 9133  2013-01-04      6     1      7    2013-01
# 9134  2013-01-05      6     1     12    2013-01
# 10956 2013-01-01      7     1      7    2013-01
# 10957 2013-01-02      7     1      4    2013-01
# 10958 2013-01-03      7     1      8    2013-01
# 10959 2013-01-04      7     1      7    2013-01
# 10960 2013-01-05      7     1      8    2013-01
# 12782 2013-01-01      8     1     16    2013-01
# 12783 2013-01-02      8     1     10    2013-01
# 12784 2013-01-03      8     1     12    2013-01
# 12785 2013-01-04      8     1     21    2013-01
# 12786 2013-01-05      8     1     15    2013-01
# 14608 2013-01-01      9     1     11    2013-01
# 14609 2013-01-02      9     1      9    2013-01
# 14610 2013-01-03      9     1     20    2013-01
# 14611 2013-01-04      9     1     22    2013-01
# 14612 2013-01-05      9     1     22    2013-01
# 16434 2013-01-01     10     1     14    2013-01
# 16435 2013-01-02     10     1     14    2013-01
# 16436 2013-01-03     10     1     16    2013-01
# 16437 2013-01-04     10     1     17    2013-01
# 16438 2013-01-05     10     1     12    2013-01

# %%
df.groupby(by='store').head()
# Out:
#             date  store  item  sales year_month
# 0     2013-01-01      1     1     13    2013-01
# 1     2013-01-02      1     1     11    2013-01
# 2     2013-01-03      1     1     14    2013-01
# 3     2013-01-04      1     1     13    2013-01
# 4     2013-01-05      1     1     10    2013-01
# 1826  2013-01-01      2     1     12    2013-01
# 1827  2013-01-02      2     1     16    2013-01
# 1828  2013-01-03      2     1     16    2013-01
# 1829  2013-01-04      2     1     20    2013-01
# 1830  2013-01-05      2     1     16    2013-01
# 3652  2013-01-01      3     1     19    2013-01
# 3653  2013-01-02      3     1      8    2013-01
# 3654  2013-01-03      3     1     10    2013-01
# 3655  2013-01-04      3     1     15    2013-01
# 3656  2013-01-05      3     1     22    2013-01
# 5478  2013-01-01      4     1     10    2013-01
# 5479  2013-01-02      4     1     12    2013-01
# 5480  2013-01-03      4     1      8    2013-01
# 5481  2013-01-04      4     1     15    2013-01
# 5482  2013-01-05      4     1     19    2013-01
# 7304  2013-01-01      5     1     11    2013-01
# 7305  2013-01-02      5     1      9    2013-01
# 7306  2013-01-03      5     1     12    2013-01
# 7307  2013-01-04      5     1      8    2013-01
# 7308  2013-01-05      5     1     13    2013-01
# 9130  2013-01-01      6     1     20    2013-01
# 9131  2013-01-02      6     1      6    2013-01
# 9132  2013-01-03      6     1     11    2013-01
# 9133  2013-01-04      6     1      7    2013-01
# 9134  2013-01-05      6     1     12    2013-01
# 10956 2013-01-01      7     1      7    2013-01
# 10957 2013-01-02      7     1      4    2013-01
# 10958 2013-01-03      7     1      8    2013-01
# 10959 2013-01-04      7     1      7    2013-01
# 10960 2013-01-05      7     1      8    2013-01
# 12782 2013-01-01      8     1     16    2013-01
# 12783 2013-01-02      8     1     10    2013-01
# 12784 2013-01-03      8     1     12    2013-01
# 12785 2013-01-04      8     1     21    2013-01
# 12786 2013-01-05      8     1     15    2013-01
# 14608 2013-01-01      9     1     11    2013-01
# 14609 2013-01-02      9     1      9    2013-01
# 14610 2013-01-03      9     1     20    2013-01
# 14611 2013-01-04      9     1     22    2013-01
# 14612 2013-01-05      9     1     22    2013-01
# 16434 2013-01-01     10     1     14    2013-01
# 16435 2013-01-02     10     1     14    2013-01
# 16436 2013-01-03     10     1     16    2013-01
# 16437 2013-01-04     10     1     17    2013-01
# 16438 2013-01-05     10     1     12    2013-01

# %%
df.groupby(by=['store', 'sales']).agg(sales_agg=pd.NamedAgg(column="sales", aggfunc="count"))
# Out:
#              sales_agg
# store sales
# 1     1              1
#       3              6
#       4             15
#       5             42
#       6             73
# ...                ...
# 10    178            1
#       180            2
#       181            1
#       183            1
#       187            1
#
# [1628 rows x 1 columns]

# %%
df.groupby(by='store').sales.agg

# %%
df.groupby(by=['store', 'sales']).agg({'sales': 'count'})
# Out:
#              store
# store sales
# 1     1          1
#       3          6
#       4         15
#       5         42
#       6         73
# ...            ...
# 10    178        1
#       180        2
#       181        1
#       183        1
#       187        1
#
# [1628 rows x 1 columns]

# %%
df_g.agg?

# %%
df_g['store', 'sales'].apply?
# Out:
# Object `apply` not found.

# %%
df_g.agg?

# %%
df.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %%
df.groupby(['store','sales']).size()
# Out:
# store  sales
# 1      1         1
#        3         6
#        4        15
#        5        42
#        6        73
#                 ..
# 10     178       1
#        180       2
#        181       1
#        183       1
#        187       1
# Length: 1628, dtype: int64

# %%
df_grouped = df.groupby(['store']).agg({'sales':'sum'})

# %%
df_grouped
# Out:
#          sales
# store
# 1      4315603
# 2      6120128
# 3      5435144
# 4      5012639
# 5      3631016
# 6      3627670
# 7      3320009
# 8      5856169
# 9      5025976
# 10     5360158

# %%
plt.figure()

# %%
grouped = df.groupby(['year_month']).agg({'sales':'sum'})

# %%
grouped
# Out:
#               sales
# year_month
# 2013-01      454904
# 2013-02      459417
# 2013-03      617382
# 2013-04      682274
# 2013-05      763242
# 2013-06      795597
# 2013-07      855922
# 2013-08      766761
# 2013-09      689907
# 2013-10      656587
# 2013-11      692643
# 2013-12      506607
# 2014-01      525987
# 2014-02      529117
# 2014-03      704301
# 2014-04      788914
# 2014-05      882877
# 2014-06      906842
# 2014-07      989010
# 2014-08      885596
# 2014-09      785124
# 2014-10      758883
# 2014-11      800783
# 2014-12      578048
# 2015-01      552513
# 2015-02      551317
# 2015-03      730951
# 2015-04      824467
# 2015-05      926902
# 2015-06      937184
# 2015-07     1037350
# 2015-08      920401
# 2015-09      823332
# 2015-10      797253
# 2015-11      827645
# 2015-12      607572
# 2016-01      602439
# 2016-02      614957
# 2016-03      790881
# 2016-04      901950
# 2016-05      988730
# 2016-06     1022664
# 2016-07     1138718
# 2016-08      981494
# 2016-09      896831
# 2016-10      863637
# 2016-11      891448
# 2016-12      663411
# 2017-01      617306
# 2017-02      621369
# 2017-03      822667
# 2017-04      938862
# 2017-05     1020686
# 2017-06     1064624
# 2017-07     1171393
# 2017-08     1026403
# 2017-09      935263
# 2017-10      891160
# 2017-11      928837
# 2017-12      695170

# %%
df.groupby('store')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar')
plt.show()

# %%
df.groupby('year_month')[['sales']].sum().sort_values(by='year_month', ascending=True).plot(kind='bar')
plt.show()

# %%
df.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar', subplots=True, layout=(5,1), sharex=False, figsize=(16,16) )
plt.show()

# %%
df.groupby('month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar')

# %%
df_2013 = df[df['year']==2013]

# %%
df_2013.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar' ,color = 'orange')
plt.show()

# %%
df_2014 = df[df['year']==2014]

# %%
df_2014.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar',color = 'orange' )
plt.show()

# %%
df_2015 = df[df['year']==2015]

# %%
df_2015.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar' ,color = 'orange')
plt.show()

# %%
df_2016 = df[df['year']==2016]

# %%
df_2016.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar',color = 'orange' )
plt.show()

# %%
df_2017 = df[df['year']==2017]

# %%
df_2017.groupby('year_month')[['sales']].sum().sort_values(by='sales', ascending=True).plot(kind='bar',color = 'orange' )
plt.show()
